# %%
from astroquery.mast import Observations
def search_hst_spectrum(star_name):
    # Buscar observaciones de espectros estelares en MAST por el nombre de la estrella
    observations = Observations.query_criteria(target_name=star_name, obs_collection='TUES', dataproduct_type='spectrum')
    # observations = Observations.query_criteria(target_name=star_name, obs_collection='*', dataproduct_type='image')
    return observations
if __name__ == "__main__":
    # Nombre de la estrella
    star_name = '*'
    # Buscar observaciones de espectros estelares por el nombre de la estrella
    observations = search_hst_spectrum(star_name)
    # Mostrar los resultados de la búsqueda
    print(observations)
# Out:
# intentType obs_collection provenance_name ... srcDen obsid  objID
# ---------- -------------- --------------- ... ------ ------ ------
#    science           TUES              -- ... 5885.0 388966 615844
#    science           TUES              -- ... 5885.0 388967 615845
#    science           TUES              -- ... 5885.0 388968 615846
#    science           TUES              -- ... 5885.0 388969 615847
#    science           TUES              -- ... 5885.0 388970 615848
#    science           TUES              -- ... 5885.0 388971 615849
#    science           TUES              -- ... 5885.0 388972 615850
#    science           TUES              -- ... 5885.0 388973 615851
#    science           TUES              -- ... 5885.0 388974 615852
#    science           TUES              -- ... 5885.0 388975 615853
#        ...            ...             ... ...    ...    ...    ...
#    science           TUES              -- ... 5885.0 389141 616019
#    science           TUES              -- ... 5885.0 389142 616020
#    science           TUES              -- ... 5885.0 389143 616021
#    science           TUES              -- ... 5885.0 389144 616022
#    science           TUES              -- ... 5885.0 389145 616023
#    science           TUES              -- ... 5885.0 389146 616024
#    science           TUES              -- ... 5885.0 389147 616025
#    science           TUES              -- ... 5885.0 389148 616026
#    science           TUES              -- ... 5885.0 389149 616027
#    science           TUES              -- ... 5885.0 389150 616028
#    science           TUES              -- ... 5885.0 389151 616029
# Length = 186 rows

# %% [markdown]
# https://astroquery.readthedocs.io/en/latest/mast/mast.html

# %%
import numpy as np

a = np.unique(observations["obs_collection"])
a
# Out:
# <MaskedColumn name='obs_collection' dtype='str10' length=13>
#       BEFS
#       EUVE
# FIMS-SPEAR
#       FUSE
#      GALEX
#        HLA
#       HLSP
#        HST
#        HUT
#        IUE
#       JWST
#       TUES
#      WUPPE

# %%
print(Observations.query_criteria_count(dataproduct_type="image",filters=["NUV","FUV"],t_max=[52264.4586,54452.8914]))

# %%
print("Lista de misiones\n",Observations.list_missions())
# Out:
# Lista de misiones
#  ['HLA', 'HST', 'EUVE', 'TUES', 'HLSP', 'JWST', 'SPITZER_SHA', 'OPO', 'WUPPE', 'IUE', 'BEFS', 'FIMS-SPEAR', 'HUT', 'GALEX', 'Kepler', 'KeplerFFI', 'TESS', 'K2', 'K2FFI', 'SWIFT', 'FUSE', 'PS1']

# %%
observations
# Out:
# <Table masked=True length=50000>
# intentType obs_collection provenance_name ...  srcDen  obsid     objID
#    str7         str4            str4      ... float64   str8      str9
# ---------- -------------- --------------- ... ------- -------- ---------
#    science           TESS            SPOC ...     nan 63393637 119031722
#    science           TESS            SPOC ...     nan 63393638 119031723
#    science           TESS            SPOC ...     nan 63393639 119031724
#    science           TESS            SPOC ...     nan 63393643 119031725
#    science           TESS            SPOC ...     nan 63393642 119031726
#    science           TESS            SPOC ...     nan 63393640 119031727
#    science           TESS            SPOC ...     nan 63393645 119031728
#    science           TESS            SPOC ...     nan 63393644 119031729
#    science           TESS            SPOC ...     nan 63393652 119031730
#    science           TESS            SPOC ...     nan 63393654 119031731
#        ...            ...             ... ...     ...      ...       ...
#    science           TESS            SPOC ...     nan 63416876 119187250
#    science           TESS            SPOC ...     nan 63416878 119187252
#    science           TESS            SPOC ...     nan 63416880 119187254
#    science           TESS            SPOC ...     nan 63416881 119187256
#    science           TESS            SPOC ...     nan 63416882 119187257
#    science           TESS            SPOC ...     nan 63416883 119187259
#    science           TESS            SPOC ...     nan 63416885 119187262
#    science           TESS            SPOC ...     nan 63416886 119187264
#    science           TESS            SPOC ...     nan 63416884 119187265
#    science           TESS            SPOC ...     nan 63416888 119187269

# %% [markdown]
# ## QUERY KWARG*
# https://mast.stsci.edu/api/v0/_c_a_o_mfields.html

# %% [markdown]
# ## TABLE LIBRERIAS

# %% [markdown]
# obs_table = Observations.query_region("322.49324 12.16683")

# %% [markdown]
# ## busca por region

# %%
obs_table = Observations.query_region("322.49324 12.16683",radius=".002 deg")
obs_table

# %% [markdown]
# ## busca por objeto

# %%
obs_table = Observations.query_object("M31",radius="0.0002 deg")
obs_table

# %%
observations[:100].show_in_notebook()

# %% [markdown]
# # descargar

# %%
a=observations[10:20]
a
# Out:
# <Table masked=True length=10>
# intentType obs_collection provenance_name ...  srcDen obsid  objID
#    str7         str5            str3      ... float64  str6   str6
# ---------- -------------- --------------- ... ------- ------ ------
#    science          GALEX             GIS ...  5885.0 240276 433635
#    science          GALEX             GIS ...  5885.0 240276 433636
#    science          GALEX             GIS ...  5885.0 240279 433641
#    science          GALEX             GIS ...  5885.0 240279 433642
#    science          GALEX             GIS ...  5885.0 240284 433651
#    science          GALEX             CAS ...  5885.0 264777 482637
#    science          GALEX             CAS ...  5885.0 264777 482638
#    science          GALEX             CAS ...  5885.0 264779 482641
#    science          GALEX             CAS ...  5885.0 264779 482642
#    science          GALEX             CAS ...  5885.0 264788 482659

# %%
product_list = Observations.get_product_list(a)
spectrum = Observations.download_products(product_list, download_dir='./prueba/')
# Out:
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:GALEX/url/data/GR6/pipe/01-vsn/25117-GI5_054006_VY_UMa/g/01-main/0001-img/07-try/qa/spjpeg/GI5_054006_VY_UMa_id009409-ng-prc_int.jpeg to ./prueba/mastDownload/GALEX/3189573418518324417/GI5_054006_VY_UMa_id009409-ng-prc_int.jpeg ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast
... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:GALEX/url/data/GR6/pipe/01-vsn/30063-WDST_GD_50/g/01-main/0001-img/07-try/SSAP/3363595322871778466.fits to ./prueba/mastDownload/GALEX/3363595322871778466/3363595322871778466.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:GALEX/url/data/GR6/pipe/01-vsn/30063-WDST_GD_50/g/01-main/0001-img/07-try/qa/spjpeg/WDST_GD_50_id003315-fg-prc_int.jpeg to ./prueba/mastDownload/GALEX/3363595322871778547/WDST_GD_50_id003315-fg-prc_int.jpeg ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:GALEX/url/data/GR6/pipe/01-vsn/30063-WDST_GD_50/g/01-main/0001-img/07-try/qa/spjpeg/WDST_GD_50_id003315-ng-prc_int.jpeg to ./prueba/mastDownload/GALEX/3363595322871778547/WDST_GD_50_id003315-ng-prc_int.jpeg ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:GALEX/url/data/GR6/pipe/01-vsn/30063-WDST_GD_50/g/01-main/0001-img/07-try/qa/spjpeg/WDST_GD_50_id003315-xg-gsp_spc.jpeg to ./prueba/mastDownload/GALEX/3363595322871778547/WDST_GD_50_id003315-xg-gsp_spc.jpeg ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:GALEX/url/data/GR6/pipe/01-vsn/30063-WDST_GD_50/g/01-main/0001-img/07-try/SSAP/3363595322871778547.fits to ./prueba/mastDownload/GALEX/3363595322871778547/3363595322871778547.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:GALEX/url/data/GR6/pipe/01-vsn/30095-WDST_GRW_p70d5824/g/01-main/0001-img/07-try/qa/spjpeg/WDST_GRW_p70d5824_id001509-fg-prc_int.jpeg to ./prueba/mastDownload/GALEX/3364721222778619365/WDST_GRW_p70d5824_id001509-fg-prc_int.jpeg ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:GALEX/url/data/GR6/pipe/01-vsn/30095-WDST_GRW_p70d5824/g/01-main/0001-img/07-try/qa/spjpeg/WDST_GRW_p70d5824_id001509-ng-prc_int.jpeg to ./prueba/mastDownload/GALEX/3364721222778619365/WDST_GRW_p70d5824_id001509-ng-prc_int.jpeg ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:GALEX/url/data/GR6/pipe/01-vsn/30095-WDST_GRW_p70d5824/g/01-main/0001-img/07-try/qa/spjpeg/WDST_GRW_p70d5824_id001509-xg-gsp_spc.jpeg to ./prueba/mastDownload/GALEX/3364721222778619365/WDST_GRW_p70d5824_id001509-xg-gsp_spc.jpeg ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:GALEX/url/data/GR6/pipe/01-vsn/30095-WDST_GRW_p70d5824/g/01-main/0001-img/07-try/SSAP/3364721222778619365.fits to ./prueba/mastDownload/GALEX/3364721222778619365/3364721222778619365.fits ... [Done]

# %% [markdown]
# ## filtros para descarga:
# https://mast.stsci.edu/api/v0/_productsfields.html
# Observations.download_products('25119363',
#                                productType=["SCIENCE", "PREVIEW"],
#                                extension="fits")

# %% [markdown]
# ## misiones

# %%
from astroquery.mast import MastMissions
missions = MastMissions(mission='hst')
columns = missions.get_column_list()
columns
