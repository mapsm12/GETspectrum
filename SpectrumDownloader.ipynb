# %%
from astroquery.mast import Observations

def search_hst_spectrum(star_name):
    # Buscar observaciones de espectros estelares en MAST por el nombre de la estrella
    observations = Observations.query_criteria(target_name=star_name, obs_collection='HST', dataproduct_type='spectrum')
    # observations = Observations.query_criteria(target_name=star_name, obs_collection='*', dataproduct_type='image')

    return observations

if __name__ == "__main__":
    # Nombre de la estrella
    star_name = '*'

    # Buscar observaciones de espectros estelares por el nombre de la estrella
    observations = search_hst_spectrum(star_name)

    # Mostrar los resultados de la búsqueda
    print(observations)

# %% [markdown]
# https://astroquery.readthedocs.io/en/latest/mast/mast.html

# %%
print(Observations.query_criteria_count(dataproduct_type="image",
                                        filters=["NUV","FUV"],
                                        t_max=[52264.4586,54452.8914]))

# %%
print("Lista de misiones\n",Observations.list_missions())

# %% [markdown]
# ## QUERY KWARG*
# https://mast.stsci.edu/api/v0/_c_a_o_mfields.html

# %% [markdown]
# ## TABLE LIBRERIAS

# %% [markdown]
# obs_table = Observations.query_region("322.49324 12.16683")

# %% [markdown]
# ## busca por region

# %%
obs_table = Observations.query_region("322.49324 12.16683",radius=".002 deg")
obs_table

# %% [markdown]
# ## busca por objeto

# %%
obs_table = Observations.query_object("M31",radius="0.02 deg")
obs_table
# Out:
# <Table masked=True length=2323>
# intentType obs_collection provenance_name ...  srcDen   obsid   distance
#   str11        str11           str31      ... float64    str9   float64
# ---------- -------------- --------------- ... ------- --------- --------
#    science           TESS            SPOC ...     nan  27584813      0.0
#    science           TESS            SPOC ...     nan 103128538      0.0
#    science           TESS            SPOC ...     nan  27560829      0.0
#    science           TESS            SPOC ...     nan 101311936      0.0
#    science          SWIFT              -- ...  5885.0   1516972      0.0
#    science          SWIFT              -- ...  5885.0   1519623      0.0
#    science          SWIFT              -- ...  5885.0   1519624      0.0
#    science          SWIFT              -- ...  5885.0   1521638      0.0
#    science          SWIFT              -- ...  5885.0   1516975      0.0
# ...

# %%
observations[:10].show_in_notebook()
# Out:
# <i>Table length=10</i>
# <table id="table140400341886432-445457" class="table-striped table-bordered table-condensed">
# <thead><tr><th>idx</th><th>intentType</th><th>obs_collection</th><th>provenance_name</th><th>instrument_name</th><th>project</th><th>filters</th><th>wavelength_region</th><th>target_name</th><th>target_classification</th><th>obs_id</th><th>s_ra</th><th>s_dec</th><th>dataproduct_type</th><th>proposal_pi</th><th>calib_level</th><th>t_min</th><th>t_max</th><th>t_exptime</th><th>em_min</th><th>em_max</th><th>obs_title</th><th>t_obs_release</th><th>proposal_id</th><th>proposal_type</th><th>sequence_number</th><th>s_region</th><th>jpegURL</th><th>dataURL</th><th>dataRights</th><th>mtFlag</th><th>srcDen</th><th>obsid</th><th>objID</th></tr></thead>
# ...

# %%
a=observations[observations["obs_id"]=="o8uh43d5q"]
a
# Out:
# <Table masked=True length=1>
#  intentType obs_collection provenance_name ...  srcDen  obsid     objID
#    str11         str3            str7      ... float64   str9      str9
# ----------- -------------- --------------- ... ------- -------- ---------
# calibration            HST         CALSTIS ...     nan 24512144 235989243

# %%
product_list = Observations.get_product_list(a)
spectrum = Observations.download_products(product_list, download_dir='./lista/')

# %% [markdown]
# ## filtros para descarga:
# https://mast.stsci.edu/api/v0/_productsfields.html
# Observations.download_products('25119363',
#                                productType=["SCIENCE", "PREVIEW"],
#                                extension="fits")

# %% [markdown]
# ## misiones

# %%
from astroquery.mast import MastMissions
missions = MastMissions(mission='hst')
columns = missions.get_column_list()
columns
# Out:
# <Table length=55>
#         name        ...
#        str22        ...
# ------------------- ...
#          search_pos ...
#   sci_data_set_name ...
#   sci_archive_class ...
#      sci_program_id ...
#        sci_obset_id ...
#          sci_obsnum ...
#          sci_asn_id ...
#        sci_targname ...
#  sci_target_descrip ...
#  sci_broad_category ...
#                 ... ...
#      sci_fov_config ...
# sci_generation_date ...
#    sci_archive_date ...
#    sci_preview_name ...
#        sci_obs_type ...
#       scp_scan_type ...
#            sci_hlsp ...
#             ang_sep ...
#          sci_status ...
#          search_key ...
